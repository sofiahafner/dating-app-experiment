# %%
import pandas as pd
import itertools
import random
random.seed(0)

# %%
hobbies_dict = {
    "Sport": [
        "Tennis", "Soccer", "Basketball", "Baseball", "Volleyball",
        "Swimming", "Cycling", "Running", "Hiking", "Surfing",
        "Snowboarding", "Skiing", "Golf", "Boxing", "Martial Arts",
        "Rock Climbing", "Horseback Riding", "Bowling", "Yoga", "Pilates"
    ],
    "Music": [
        "Playing Guitar", "Playing Piano", "Playing Drums", "Singing",
        "Composing Music", "DJing", "Producing Music", "Writing Songs",
        "Attending Concerts", "Listening to Music", "Music Theory Study",
        "Playing Violin", "Playing Saxophone", "Karaoke", "Music Critique",
        "Playing Flute", "Playing Trumpet", "Playing Cello", "Music Collecting", "Choir Singing"
    ],
    "Art": [
        "Painting", "Drawing", "Sculpting", "Photography",
        "Graphic Design", "Animation", "Calligraphy", "Printmaking",
        "Fashion Design", "Interior Design", "Ceramics", "Woodworking",
        "Jewelry Making", "Digital Art", "Street Art", "Mosaics",
        "Film Making", "Theater", "Dance", "Architecture"
    ],
    "Travel": [
        "Backpacking", "Cruising", "Road Tripping", "Mountain Climbing",
        "Cultural Tourism", "Eco-Tourism", "Adventure Tourism", "Volunteer Tourism",
        "Historical Tourism", "Luxury Travel", "Camping", "Beach Holidays",
        "City Breaks", "Safari", "Ski Trips", "Food Tourism",
        "Island Hopping", "Scuba Diving", "Spa Visits", "Business Travel"
    ]
}

# %%
ethnicities = ["White", "South Asian", "East Asian", "Black", "Hispanic"]
genders = ["Man", "Woman", "Androgynous Person"]
hobbies = ["Sport", "Music", "Art", "Travel"]
age_ranges = ["20-30", "31-40", "41-50"]
tone = ["fun", "serious"]
size = ["thin", "mid-size", "plus-size"]
combinations = list(itertools.product(ethnicities, genders, hobbies, age_ranges, size, tone))
df = pd.DataFrame(combinations, columns=["Ethnicity", "Gender", "Hobby", "Age Range", "Size", "Tone"])
# df['Profile_ID'] = range(1, len(df) + 1)

# %%
def get_two_specific_hobbies(hobby_category):
    sub_hobbies = hobbies_dict[hobby_category]
    return random.sample(sub_hobbies, 2)

df[['SpecificHobby1', 'SpecificHobby2']] = df['Hobby'].apply(lambda x: pd.Series(get_two_specific_hobbies(x)))


def get_random_age_from_range(age_range):
    start_age, end_age = map(int, age_range.split('-'))
    return random.randint(start_age, end_age)

df['Age'] = df['Age Range'].apply(get_random_age_from_range)

# %%
eye_colors = {
    'default': ["brown", "green", "hazel"],
    'White': ["brown", "blue", "green", "hazel"]
}
hair_colors = {
    'default': ["black", "brown"],
    'White': ["black", "blonde", "brown", "red"]
}
dyed_hair_colors = ["dyed blonde", "dyed red"]
hair_lengths = ["short", "medium length", "long"]
hair_texture = ["curly", "wavy", "straight"]
clothing_styles = ["casual", "formal", "sporty", "vintage"]
nose_sizes = ["small", "medium", "large"]
eye_sizes = ["small", "medium", "large"]
lip_sizes = ["narrow", "medium", "full"]

random.seed(0)

def assign_features(row):
    if row['Ethnicity'] in ['Black', 'East Asian', 'South Asian']:
        hair_color = random.choice(dyed_hair_colors)
        eye_color = random.choice(eye_colors['default'])
    else:
        hair_color = random.choice(hair_colors['White'])
        eye_color = random.choice(eye_colors['White'])
    
    return pd.Series({
        'Eye Color': eye_color,
        'Hair Color': hair_color,
        'Hair Length': random.choice(hair_lengths),
        'Hair Texture': random.choice(hair_texture),
        'Clothing Style': random.choice(clothing_styles),
        'Nose Size': random.choice(nose_sizes),
        'Eye Size': random.choice(eye_sizes),
        'Lip Size': random.choice(lip_sizes)
    })

df[['Eye Color', 'Hair Color', 'Hair Length', 'Hair Texture', 'Clothing Style', 'Nose Size', 'Eye Size', 'Lip Size']] = df.apply(assign_features, axis=1)

def create_detailed_prompt(row):
    return (
        f"Create a photo-realistic profile picture for a {row['Size']}, {row['Age']} year-old {row['Ethnicity']} {row['Gender'].lower()} with "
        f"{row['Eye Size']} {row['Eye Color']} eyes, {row['Hair Length']} "
        f"{row['Hair Color']} {row['Hair Texture']} hair, "
        f"a {row['Nose Size']} nose, and {row['Lip Size']} lips, "
        f"dressed in {row['Clothing Style']} style, standing in front of a white backdrop. "
        f"Make the image look like a realistic person, not following beauty standards."
    )

df['Dalle Prompt'] = df.apply(create_detailed_prompt, axis=1)

df
# Out:
#      Ethnicity              Gender   Hobby Age Range       Size     Tone  \
# 0        White                 Man   Sport     20-30       thin      fun
# 1        White                 Man   Sport     20-30       thin  serious
# 2        White                 Man   Sport     20-30   mid-size      fun
# 3        White                 Man   Sport     20-30   mid-size  serious
# 4        White                 Man   Sport     20-30  plus-size      fun
# ...        ...                 ...     ...       ...        ...      ...
# 1075  Hispanic  Androgynous Person  Travel     41-50       thin  serious
# 1076  Hispanic  Androgynous Person  Travel     41-50   mid-size      fun
# 1077  Hispanic  Androgynous Person  Travel     41-50   mid-size  serious
# 1078  Hispanic  Androgynous Person  Travel     41-50  plus-size      fun
# 1079  Hispanic  Androgynous Person  Travel     41-50  plus-size  serious
#
#          SpecificHobby1  SpecificHobby2  Age Eye Color Hair Color  \
# 0                  Golf          Boxing   21     hazel        red
# 1                Soccer          Hiking   28      blue      brown
# 2      Horseback Riding   Rock Climbing   23      blue      brown
# 3                  Golf         Surfing   22     green      black
# 4         Rock Climbing          Skiing   30     brown      brown
# ...                 ...             ...  ...       ...        ...
# 1075  Mountain Climbing  Island Hopping   42      blue      black
# 1076      Road Tripping      Spa Visits   41     brown        red
# 1077   Cultural Tourism    Food Tourism   42      blue     blonde
# 1078           Cruising  Island Hopping   46     green        red
# 1079  Volunteer Tourism  Beach Holidays   44     green        red
#
#         Hair Length Hair Texture Clothing Style Nose Size Eye Size Lip Size  \
# 0             short         wavy        vintage    medium   medium   medium
# 1              long        curly         sporty     small    small     full
# 2     medium length        curly         casual     large   medium   medium
# 3     medium length         wavy         formal     large   medium   medium
# 4              long        curly         casual     large   medium     full
# ...             ...          ...            ...       ...      ...      ...
# 1075          short        curly         sporty    medium   medium   medium
# 1076           long         wavy         formal     small   medium     full
# 1077  medium length        curly         sporty     large    large   narrow
# 1078          short     straight        vintage     large    small   medium
# 1079  medium length         wavy         sporty    medium   medium   narrow
#
#                                            Dalle Prompt
# 0     Create a photo-realistic profile picture for a...
# 1     Create a photo-realistic profile picture for a...
# 2     Create a photo-realistic profile picture for a...
# 3     Create a photo-realistic profile picture for a...
# 4     Create a photo-realistic profile picture for a...
# ...                                                 ...
# 1075  Create a photo-realistic profile picture for a...
# 1076  Create a photo-realistic profile picture for a...
# 1077  Create a photo-realistic profile picture for a...
# 1078  Create a photo-realistic profile picture for a...
# 1079  Create a photo-realistic profile picture for a...
#
# [1080 rows x 18 columns]

# %%
df.iloc[722]["Dalle Prompt"]
# Out:
# 'Create a photo-realistic profile picture for a mid-size, 22 year-old Black woman with small brown eyes, short dyed red straight hair, a large nose, and full lips, dressed in vintage style, standing in front of a white backdrop. Make the image look like a realistic person, not following beauty standards.'

# %% [markdown]
# ## Create Peeps Structure:

# %%
accessories = [
#     "Eyepatch",
#     "GlassAviator",
    "GlassButterfly",
    "GlassButterflyOutline",
    "GlassClubmaster",
    "GlassRound",
    "GlassRoundThick",
    "SunglassClubmaster",
    "SunglassWayfarer"
]

faces = [
    "Angry",
    "Awe",
#     "Blank",
    "Calm",
#     "CalmNM",
    "Cheeky",
#     "CheersNM",
    "Concerned",
    "ConcernedFear",
    "Contempt",
    "Cute",
    "Driven",
    "EatingHappy",
    "Explaining",
    "EyesClosed",
    "Fear",
    "Hectic",
    "LoveGrin",
    "LoveGrinTeeth",
#     "Monster",
    "OldAged",
    "Rage",
    "Serious",
    "Smile",
    "SmileBig",
    "SmileLol",
#     "SmileNM",
    "SmileTeeth",
    "Solemn",
    "Suspicious",
    "Tired",
    "VeryAngry"
]

facial_hair = [
    "Chin",
    "Dali",
    "Full",
    "FullMajestic",
    "FullMedium",
    "Goatee",
    "GoateeCircle",
    "GrayFull",
    "Handlebars",
    "Imperial",
    "MajesticHandlebars",
    "MoustacheThin",
    "Painters",
    "PaintersFilled",
    "Swashbuckler",
    "Yosemite"
]

hair = [
    "Afro",
    "Bald",
    "BaldSides",
    "BaldTop",
    "Bangs",
    "BangsFilled",
    "BantuKnots",
    "Beanie",
    "Bear",
    "Bun",
    "BunCurly",
    "BunFancy",
    "Buns",
    "CornRows",
    "CornRowsFilled",
#     "DocBouffant",
#     "DocShield",
#     "DocSurgery",
    "FlatTop",
    "FlatTopLong",
    "GrayBun",
    "GrayMedium",
    "GrayShort",
    "HatHip",
    "Hijab",
    "Long",
    "LongAfro",
    "LongBangs",
    "LongCurly",
    "Medium",
    "MediumBangs",
    "MediumBangsFilled",
    "MediumLong",
    "MediumShade",
    "MediumShort",
    "MediumStraight",
    "Mohawk",
    "MohawkDino",
    "Pomp",
    "ShavedRight",
    "ShavedSides",
    "ShavedWavy",
    "Short",
    "ShortCurly",
    "ShortMessy",
    "ShortScratch",
    "ShortVolumed",
    "ShortWavy",
    "Turban",
    "Twists",
    "TwistsVolumed"
]

poses = [
    "ArmsCrossed",
    "BlazerBlackTee",
    "ButtonShirt",
    "Coffee",
    "Device",
    "DotJacket",
    "Dress",
    "Explaining",
    "FurJacket",
    "Gaming",
    "Geek",
    "Hoodie",
#     "Killer",
    "Paper",
    "PocketShirt",
    "PointingUp",
    "PoloSweater",
    "Selena",
    "Shirt",
    "ShirtCoat",
    "ShirtFilled",
    "SportyShirt",
    "StripedShirt",
    "Sweater",
    "SweaterDots",
    "Thunder",
    "Turtleneck"
]

skin_tones = ["#ffe7d1", "#3b2219","#a16e4b", "#d4aa78", "#e6bc98"]

hobbies_dict = {
    "Sport": [
        "Tennis", "Soccer", "Basketball", "Baseball", "Volleyball",
        "Swimming", "Cycling", "Running", "Hiking", "Surfing",
        "Snowboarding", "Skiing", "Golf", "Boxing", "Martial Arts",
        "Rock Climbing", "Horseback Riding", "Bowling", "Yoga", "Pilates"
    ],
    "Music": [
        "Playing Guitar", "Playing Piano", "Playing Drums", "Singing",
        "Composing Music", "DJing", "Producing Music", "Writing Songs",
        "Attending Concerts", "Listening to Music", "Music Theory Study",
        "Playing Violin", "Playing Saxophone", "Karaoke", "Music Critique",
        "Playing Flute", "Playing Trumpet", "Playing Cello", "Music Collecting", "Choir Singing"
    ],
    "Art": [
        "Painting", "Drawing", "Sculpting", "Photography",
        "Graphic Design", "Animation", "Calligraphy", "Printmaking",
        "Fashion Design", "Interior Design", "Ceramics", "Woodworking",
        "Jewelry Making", "Digital Art", "Street Art", "Mosaics",
        "Film Making", "Theater", "Dance", "Architecture"
    ],
    "Travel": [
        "Backpacking", "Cruising", "Road Tripping", "Mountain Climbing",
        "Cultural Tourism", "Eco-Tourism", "Adventure Tourism", "Volunteer Tourism",
        "Historical Tourism", "Luxury Travel", "Camping", "Beach Holidays",
        "City Breaks", "Safari", "Ski Trips", "Food Tourism",
        "Island Hopping", "Scuba Diving", "Spa Visits", "Business Travel"
    ]
}

# %%
df = pd.DataFrame({'profile_ID': range(1, 501)})

def assign_peep_features(row):
    peep_accessories = random.choice(accessories) if random.random() > 0.3 else ""
    peep_face = random.choice(faces)
    peep_facial_hair = random.choice(facial_hair) if random.random() > 0.3 else ""
    peep_hair = random.choice(hair)
    peep_pose = random.choice(poses)
    main_hobby = random.choice(["Sport", "Music", "Art", "Travel"])
    skin_tone = random.choice(skin_tones)
    age = 25
    hobby_1 = random.choice(hobbies_dict[main_hobby])
    hobby_2 = random.choice(hobbies_dict[main_hobby])

    return pd.Series({
        'accessories': peep_accessories,
        'face': peep_face,
        'facial_hair': peep_facial_hair,
        'hair': peep_hair,
        'pose': peep_pose,
        'skin_tone': skin_tone,
        'age': age,
        'hobby_1': hobby_1,
        'hobby_2': hobby_2
    })

df[['accessories', 'face', 'facial_hair', 'hair', 'pose', 'skin_tone', 'age', 'hobby_1', 'hobby_2']] = df.apply(assign_peep_features, axis=1)
df
# Out:
#      profile_ID         accessories        face         facial_hair  \
# 0             1                        SmileBig        Swashbuckler
# 1             2     GlassClubmaster        Fear          FullMedium
# 2             3     GlassClubmaster   VeryAngry                Dali
# 3             4     GlassClubmaster     Serious  MajesticHandlebars
# 4             5                        LoveGrin        GoateeCircle
# ..          ...                 ...         ...                 ...
# 495         496          GlassRound      Solemn        Swashbuckler
# 496         497                            Cute            Imperial
# 497         498      GlassButterfly        Cute
# 498         499                      Suspicious              Goatee
# 499         500  SunglassClubmaster   VeryAngry          FullMedium
#
#              hair         pose skin_tone  age            hobby_1  \
# 0    ShortVolumed  ButtonShirt   #a16e4b   25            Bowling
# 1          Twists      Sweater   #3b2219   25            Bowling
# 2       GrayShort       Gaming   #a16e4b   25  Playing Saxophone
# 3        CornRows  ShirtFilled   #3b2219   25           Baseball
# 4            Buns        Dress   #d4aa78   25    Interior Design
# ..            ...          ...       ...  ...                ...
# 495    MohawkDino       Gaming   #ffe7d1   25            Camping
# 496     GrayShort         Geek   #d4aa78   25             Boxing
# 497        HatHip  ShirtFilled   #e6bc98   25            Karaoke
# 498          Long  PoloSweater   #a16e4b   25            Cycling
# 499   MediumShort  PocketShirt   #ffe7d1   25        Calligraphy
#
#            hobby_2
# 0       Volleyball
# 1         Baseball
# 2    Playing Drums
# 3           Boxing
# 4      Photography
# ..             ...
# 495      Ski Trips
# 496         Soccer
# 497  Playing Piano
# 498     Volleyball
# 499          Dance
#
# [500 rows x 10 columns]

# %%
df.to_json('/Users/franziskahafner/Desktop/oii/trinity/thesis/experiment/dating-app-experiment/client/data/peep_profiles.json', orient='records', lines=False)

# %%
import os

def generate_code_structure(base_path):
    categories = ["accessory", "beard", "body/effigy", "face", "head"]
    code_lines = []

    for category in categories:
        folder_path = os.path.join(base_path, category)
        if not os.path.exists(folder_path):
            continue

        category_name = category.replace("/", "_")
        imports = []
        mappings = []

        for file_name in os.listdir(folder_path):
            if file_name.endswith(".tsx"):
                component_name = file_name.replace(".tsx", ".js")
                import_statement = f'import {component_name} from "./{category}/{file_name}";'
                imports.append(import_statement)
                mappings.append(component_name)

        if imports:
            code_lines.extend(imports)
            code_lines.append("")

            mapping_name = f"{category_name}Components"
            mapping_dict = ",\n    ".join(mappings)
            mapping_code = f"const {mapping_name} = {{\n    {mapping_dict},\n}};"
            code_lines.append(mapping_code)
            code_lines.append("")

    complete_code = "\n".join(code_lines)
    print(complete_code)

# Replace with the path to your base folder
base_folder_path = "/Users/franziskahafner/Desktop/oii/trinity/thesis/experiment/dating-app-experiment/client/open-peeps/lib"
generate_code_structure(base_folder_path)
# Out:
# import GlassesThree.tsx from "./accessory/GlassesThree.tsx";
# import GlassesFour.tsx from "./accessory/GlassesFour.tsx";
# import GlassesFive.tsx from "./accessory/GlassesFive.tsx";
# import SunglassesTwo.tsx from "./accessory/SunglassesTwo.tsx";
# import GlassesSix.tsx from "./accessory/GlassesSix.tsx";
# import GlassesTwo.tsx from "./accessory/GlassesTwo.tsx";
# import Glasses.tsx from "./accessory/Glasses.tsx";
# import Sunglasses.tsx from "./accessory/Sunglasses.tsx";
# import Eyepatch.tsx from "./accessory/Eyepatch.tsx";
#
# const accessoryComponents = {
#     GlassesThree.tsx,
#     GlassesFour.tsx,
#     GlassesFive.tsx,
#     SunglassesTwo.tsx,
#     GlassesSix.tsx,
#     GlassesTwo.tsx,
#     Glasses.tsx,
#     Sunglasses.tsx,
#     Eyepatch.tsx,
# };
#
# import MustacheThin.tsx from "./beard/MustacheThin.tsx";
# import FullColor.tsx from "./beard/FullColor.tsx";
# import MustacheEight.tsx from "./beard/MustacheEight.tsx";
# import GoateeFull.tsx from "./beard/GoateeFull.tsx";
# import MustacheYosemite.tsx from "./beard/MustacheYosemite.tsx";
# import MustacheSeven.tsx from "./beard/MustacheSeven.tsx";
# import MustacheFive.tsx from "./beard/MustacheFive.tsx";
# import MustacheThinBull.tsx from "./beard/MustacheThinBull.tsx";
# import FullMedium.tsx from "./beard/FullMedium.tsx";
# import MustacheBull.tsx from "./beard/MustacheBull.tsx";
# import Goatee.tsx from "./beard/Goatee.tsx";
# import Chin.tsx from "./beard/Chin.tsx";
# import MustacheNine.tsx from "./beard/MustacheNine.tsx";
# import MustacheSix.tsx from "./beard/MustacheSix.tsx";
# import Full.tsx from "./beard/Full.tsx";
# import FullMax.tsx from "./beard/FullMax.tsx";
#
# const beardComponents = {
#     MustacheThin.tsx,
#     FullColor.tsx,
#     MustacheEight.tsx,
#     GoateeFull.tsx,
#     MustacheYosemite.tsx,
#     MustacheSeven.tsx,
#     MustacheFive.tsx,
#     MustacheThinBull.tsx,
#     FullMedium.tsx,
#     MustacheBull.tsx,
#     Goatee.tsx,
#     Chin.tsx,
#     MustacheNine.tsx,
#     MustacheSix.tsx,
#     Full.tsx,
#     FullMax.tsx,
# };
#
# import SweaterDots.tsx from "./body/effigy/SweaterDots.tsx";
# import Paper.tsx from "./body/effigy/Paper.tsx";
# import Whatever.tsx from "./body/effigy/Whatever.tsx";
# import ThunderTee.tsx from "./body/effigy/ThunderTee.tsx";
# import Coffee.tsx from "./body/effigy/Coffee.tsx";
# import PolkadotJacket.tsx from "./body/effigy/PolkadotJacket.tsx";
# import ButtonPocketShirt.tsx from "./body/effigy/ButtonPocketShirt.tsx";
# import StripedTee.tsx from "./body/effigy/StripedTee.tsx";
# import StrippedPocketTee.tsx from "./body/effigy/StrippedPocketTee.tsx";
# import PointingUp.tsx from "./body/effigy/PointingUp.tsx";
# import TeeSelena.tsx from "./body/effigy/TeeSelena.tsx";
# import Jacket.tsx from "./body/effigy/Jacket.tsx";
# import Explaining.tsx from "./body/effigy/Explaining.tsx";
# import ButtonShirt.tsx from "./body/effigy/ButtonShirt.tsx";
# import Gaming.tsx from "./body/effigy/Gaming.tsx";
# import BlazerBlackTee.tsx from "./body/effigy/BlazerBlackTee.tsx";
# import Turtleneck.tsx from "./body/effigy/Turtleneck.tsx";
# import ShirtCoat.tsx from "./body/effigy/ShirtCoat.tsx";
# import Killer.tsx from "./body/effigy/Killer.tsx";
# import Dress.tsx from "./body/effigy/Dress.tsx";
# import GymShirt.tsx from "./body/effigy/GymShirt.tsx";
# import SportyTee.tsx from "./body/effigy/SportyTee.tsx";
# import Hoodie.tsx from "./body/effigy/Hoodie.tsx";
# import PoloSweater.tsx from "./body/effigy/PoloSweater.tsx";
# import Computer.tsx from "./body/effigy/Computer.tsx";
# import TeeArmsCrossed.tsx from "./body/effigy/TeeArmsCrossed.tsx";
# import Tee.tsx from "./body/effigy/Tee.tsx";
#
# const body_effigyComponents = {
#     SweaterDots.tsx,
#     Paper.tsx,
#     Whatever.tsx,
#     ThunderTee.tsx,
#     Coffee.tsx,
#     PolkadotJacket.tsx,
#     ButtonPocketShirt.tsx,
#     StripedTee.tsx,
#     StrippedPocketTee.tsx,
#     PointingUp.tsx,
#     TeeSelena.tsx,
#     Jacket.tsx,
#     Explaining.tsx,
#     ButtonShirt.tsx,
#     Gaming.tsx,
#     BlazerBlackTee.tsx,
#     Turtleneck.tsx,
#     ShirtCoat.tsx,
#     Killer.tsx,
#     Dress.tsx,
#     GymShirt.tsx,
#     SportyTee.tsx,
#     Hoodie.tsx,
#     PoloSweater.tsx,
#     Computer.tsx,
#     TeeArmsCrossed.tsx,
#     Tee.tsx,
# };
#
# import SmileTeeth.tsx from "./face/SmileTeeth.tsx";
# import AngryFang.tsx from "./face/AngryFang.tsx";
# import LoveGrinTeeth.tsx from "./face/LoveGrinTeeth.tsx";
# import Hectic.tsx from "./face/Hectic.tsx";
# import Old.tsx from "./face/Old.tsx";
# import ConcernedFear.tsx from "./face/ConcernedFear.tsx";
# import CalmWithMask.tsx from "./face/CalmWithMask.tsx";
# import Cheeky.tsx from "./face/Cheeky.tsx";
# import SmileWithMask.tsx from "./face/SmileWithMask.tsx";
# import EatingHappy.tsx from "./face/EatingHappy.tsx";
# import Blank.tsx from "./face/Blank.tsx";
# import Explaining.tsx from "./face/Explaining.tsx";
# import Serious.tsx from "./face/Serious.tsx";
# import LoveGrinTongue.tsx from "./face/LoveGrinTongue.tsx";
# import Awe.tsx from "./face/Awe.tsx";
# import Cyclops.tsx from "./face/Cyclops.tsx";
# import Solemn.tsx from "./face/Solemn.tsx";
# import Driven.tsx from "./face/Driven.tsx";
# import Tired.tsx from "./face/Tired.tsx";
# import EyesClosed.tsx from "./face/EyesClosed.tsx";
# import CheersWithMask.tsx from "./face/CheersWithMask.tsx";
# import Calm.tsx from "./face/Calm.tsx";
# import Angry.tsx from "./face/Angry.tsx";
# import Fear.tsx from "./face/Fear.tsx";
# import BigSmile.tsx from "./face/BigSmile.tsx";
# import Contempt.tsx from "./face/Contempt.tsx";
# import Cute.tsx from "./face/Cute.tsx";
# import Concerned.tsx from "./face/Concerned.tsx";
# import Rage.tsx from "./face/Rage.tsx";
# import Suspicious.tsx from "./face/Suspicious.tsx";
# import Smile.tsx from "./face/Smile.tsx";
# import Monster.tsx from "./face/Monster.tsx";
# import SmileLOL.tsx from "./face/SmileLOL.tsx";
#
# const faceComponents = {
#     SmileTeeth.tsx,
#     AngryFang.tsx,
#     LoveGrinTeeth.tsx,
#     Hectic.tsx,
#     Old.tsx,
#     ConcernedFear.tsx,
#     CalmWithMask.tsx,
#     Cheeky.tsx,
#     SmileWithMask.tsx,
#     EatingHappy.tsx,
#     Blank.tsx,
#     Explaining.tsx,
#     Serious.tsx,
#     LoveGrinTongue.tsx,
#     Awe.tsx,
#     Cyclops.tsx,
#     Solemn.tsx,
#     Driven.tsx,
#     Tired.tsx,
#     EyesClosed.tsx,
#     CheersWithMask.tsx,
#     Calm.tsx,
#     Angry.tsx,
#     Fear.tsx,
#     BigSmile.tsx,
#     Contempt.tsx,
#     Cute.tsx,
#     Concerned.tsx,
#     Rage.tsx,
#     Suspicious.tsx,
#     Smile.tsx,
#     Monster.tsx,
#     SmileLOL.tsx,
# };
#
# import GrayShort.tsx from "./head/GrayShort.tsx";
# import Cornrows.tsx from "./head/Cornrows.tsx";
# import Shaved.tsx from "./head/Shaved.tsx";
# import HatHip.tsx from "./head/HatHip.tsx";
# import Bangs.tsx from "./head/Bangs.tsx";
# import DreadsTwo.tsx from "./head/DreadsTwo.tsx";
# import Bun.tsx from "./head/Bun.tsx";
# import ShortThree.tsx from "./head/ShortThree.tsx";
# import MediumBangsColor.tsx from "./head/MediumBangsColor.tsx";
# import LongCurly.tsx from "./head/LongCurly.tsx";
# import MediumOne.tsx from "./head/MediumOne.tsx";
# import ColorMedium.tsx from "./head/ColorMedium.tsx";
# import Mohawk.tsx from "./head/Mohawk.tsx";
# import MediumStraight.tsx from "./head/MediumStraight.tsx";
# import NoHairThree.tsx from "./head/NoHairThree.tsx";
# import DocThree.tsx from "./head/DocThree.tsx";
# import ShortOne.tsx from "./head/ShortOne.tsx";
# import ShavedOne.tsx from "./head/ShavedOne.tsx";
# import DocOne.tsx from "./head/DocOne.tsx";
# import Pomp.tsx from "./head/Pomp.tsx";
# import Beanie.tsx from "./head/Beanie.tsx";
# import ShortFour.tsx from "./head/ShortFour.tsx";
# import Turban.tsx from "./head/Turban.tsx";
# import LongHair.tsx from "./head/LongHair.tsx";
# import Wavy.tsx from "./head/Wavy.tsx";
# import FlatTopLong.tsx from "./head/FlatTopLong.tsx";
# import FlatTop.tsx from "./head/FlatTop.tsx";
# import Hijab.tsx from "./head/Hijab.tsx";
# import DocTwo.tsx from "./head/DocTwo.tsx";
# import ShortTwo.tsx from "./head/ShortTwo.tsx";
# import BunClip.tsx from "./head/BunClip.tsx";
# import MediumThree.tsx from "./head/MediumThree.tsx";
# import TwistsTwo.tsx from "./head/TwistsTwo.tsx";
# import MediumBangs.tsx from "./head/MediumBangs.tsx";
# import Twists.tsx from "./head/Twists.tsx";
# import BangsTwo.tsx from "./head/BangsTwo.tsx";
# import ShavedThree.tsx from "./head/ShavedThree.tsx";
# import ColorBun.tsx from "./head/ColorBun.tsx";
# import Afro.tsx from "./head/Afro.tsx";
# import MediumBangsOne.tsx from "./head/MediumBangsOne.tsx";
# import ShortFive.tsx from "./head/ShortFive.tsx";
# import BantuKnots.tsx from "./head/BantuKnots.tsx";
# import MohawkKnots.tsx from "./head/MohawkKnots.tsx";
# import BunTwo.tsx from "./head/BunTwo.tsx";
# import Bald.tsx from "./head/Bald.tsx";
# import NoHairTwo.tsx from "./head/NoHairTwo.tsx";
# import DreadsOne.tsx from "./head/DreadsOne.tsx";
# import LongBangs.tsx from "./head/LongBangs.tsx";
# import BunKnots.tsx from "./head/BunKnots.tsx";
# import Bear.tsx from "./head/Bear.tsx";
# import LongAfro.tsx from "./head/LongAfro.tsx";
# import CornrowsLight.tsx from "./head/CornrowsLight.tsx";
# import MediumTwo.tsx from "./head/MediumTwo.tsx";
#
# const headComponents = {
#     GrayShort.tsx,
#     Cornrows.tsx,
#     Shaved.tsx,
#     HatHip.tsx,
#     Bangs.tsx,
#     DreadsTwo.tsx,
#     Bun.tsx,
#     ShortThree.tsx,
#     MediumBangsColor.tsx,
#     LongCurly.tsx,
#     MediumOne.tsx,
#     ColorMedium.tsx,
#     Mohawk.tsx,
#     MediumStraight.tsx,
#     NoHairThree.tsx,
#     DocThree.tsx,
#     ShortOne.tsx,
#     ShavedOne.tsx,
#     DocOne.tsx,
#     Pomp.tsx,
#     Beanie.tsx,
#     ShortFour.tsx,
#     Turban.tsx,
#     LongHair.tsx,
#     Wavy.tsx,
#     FlatTopLong.tsx,
#     FlatTop.tsx,
#     Hijab.tsx,
#     DocTwo.tsx,
#     ShortTwo.tsx,
#     BunClip.tsx,
#     MediumThree.tsx,
#     TwistsTwo.tsx,
#     MediumBangs.tsx,
#     Twists.tsx,
#     BangsTwo.tsx,
#     ShavedThree.tsx,
#     ColorBun.tsx,
#     Afro.tsx,
#     MediumBangsOne.tsx,
#     ShortFive.tsx,
#     BantuKnots.tsx,
#     MohawkKnots.tsx,
#     BunTwo.tsx,
#     Bald.tsx,
#     NoHairTwo.tsx,
#     DreadsOne.tsx,
#     LongBangs.tsx,
#     BunKnots.tsx,
#     Bear.tsx,
#     LongAfro.tsx,
#     CornrowsLight.tsx,
#     MediumTwo.tsx,
# };
